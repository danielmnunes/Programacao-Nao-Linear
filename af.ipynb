# %%
import numpy as np

# %%
A = np.array([[1,0,0,1],
              [0,1,0,2],
              [0,0,1,2],
              [1,2,2,0]])

# %%
A.shape
# Out:
# (4, 4)

# %%
b = np.array([0,0,0,1])

# %%
b
# Out:
# array([0, 0, 0, 1])

# %%
x = np.linalg.solve(A, b)

# %%
x.round(3)
# Out:
# array([ 0.111,  0.222,  0.222, -0.111])

# %%
0.111111 + 2*0.222222 + 2*0.222222
# Out:
# 0.9999990000000001

# %%
A1 = np.array([[6,2,1,1,0],
               [2,5,2,0,1],
               [1,2,4,1,0],
               [1,0,1,0,0],
               [0,1,0,0,0]])

# %%
A1
# Out:
# array([[6, 2, 1, 1, 0],
#        [2, 5, 2, 0, 1],
#        [1, 2, 4, 1, 0],
#        [1, 0, 1, 0, 0],
#        [0, 1, 0, 0, 0]])

# %%
b1 = np.array([-8,-3,-3,3,0])

# %%
b1
# Out:
# array([-8, -3, -3,  3,  0])

# %%
x = np.linalg.solve(A1, b1)

# %%
x
# Out:
# array([  0.5,   0. ,   2.5, -13.5,  -9. ])

# %%
def f(x, y):
    return 10*x**2 + 5*y**2

# %%
def h(u):
    return 20*(10 - 2*u)

# %%
x = -2 * np.sqrt(2)
y = 1 + 2 * np.sqrt(2)
u = 15 + (5/(2 * np.sqrt(2)))

# %%
f(x, y)
# Out:
# 153.2842712474619

# %%
h(u)
# Out:
# -470.71067811865476
